# %%
import numpy as np
import pandas as pd

# %%
eco = pd.read_csv('/content/Economic_Times.csv')
eco.drop(columns=eco.columns[0], axis=1, inplace=True)
eco['Date']=pd.to_datetime(eco['Date'], format='%Y-%m-%d'); eco
# Out:
#                                              Headlines       Date  \
# 0    central bank india says not yet decided branch... 2022-05-08
# 1        indian bank unveils digital broking solution  2022-05-07
# 2    pm modi likely launch 75 digital banks august ... 2022-05-06
# 3    asbadesignated bank branches remain open sunda... 2022-05-05
# 4    rbi rate hike shocker home car loans get deare... 2022-05-04
# ..                                                 ...        ...
# 542  sbi looking hive yono separate subsidiary chai... 2020-10-06
# 543  banks relieved foot bill interest waiver sc as... 2020-10-05
# 544  regional rural banks incur net loss 2206 crore... 2020-10-04
# 545  kotak bank registers 170 crore fraud case cox ... 2020-10-03
# 546  rbi approves appointment cod run dhanlaxmi ban... 2020-10-02
#
#                                          Sentiment
# 0    [[9.9984145e-01 2.1175867e-06 1.5638919e-04]]
# 1    [[9.9768174e-01 2.1268544e-03 1.9137473e-04]]
# ...

# %%
sent=[]
for j in range(len(eco)):
  sent.append([float(i) for i in eco["Sentiment"][j][2:-2].split(" ") if i!=""])

# %%
len(sent)
# Out:
# 547

# %%
F = pd.DataFrame(eco)
F['Sentiment'] = sent;F
# Out:
#                                              Headlines       Date  \
# 0    central bank india says not yet decided branch... 2022-05-08
# 1        indian bank unveils digital broking solution  2022-05-07
# 2    pm modi likely launch 75 digital banks august ... 2022-05-06
# 3    asbadesignated bank branches remain open sunda... 2022-05-05
# 4    rbi rate hike shocker home car loans get deare... 2022-05-04
# ..                                                 ...        ...
# 542  sbi looking hive yono separate subsidiary chai... 2020-10-06
# 543  banks relieved foot bill interest waiver sc as... 2020-10-05
# 544  regional rural banks incur net loss 2206 crore... 2020-10-04
# 545  kotak bank registers 170 crore fraud case cox ... 2020-10-03
# 546  rbi approves appointment cod run dhanlaxmi ban... 2020-10-02
#
#                                       Sentiment
# 0    [0.99984145, 2.1175867e-06, 0.00015638919]
# 1     [0.99768174, 0.0021268544, 0.00019137473]
# ...

# %%
market_data = pd.read_csv('NIFTY BANK_Data.csv'); market_data
# Out:
#            Date      Open      High       Low     Close
# 0     06-May-22  34569.10  34797.95  34353.20  34591.20
# 1     05-May-22  35705.35  35934.85  35133.80  35232.85
# 2     04-May-22  36266.15  36309.30  35127.85  35264.55
# 3     02-May-22  35627.60  36235.25  35618.20  36163.75
# 4     29-Apr-22  36474.05  36718.80  35978.95  36088.15
# ...         ...       ...       ...       ...       ...
# 3299  07-Jan-09   5416.35   5440.55   4954.00   4984.50
# 3300  06-Jan-09   5333.50   5448.80   5276.40   5395.30
# 3301  05-Jan-09   5273.45   5371.10   5273.45   5359.40
# 3302  02-Jan-09   5154.20   5258.65   5103.60   5195.10
# 3303  01-Jan-09   5019.20   5135.15   5019.20   5116.50
#
# [3304 rows x 5 columns]

# %%
market_data['Date']=pd.to_datetime(market_data['Date'], format='%d-%b-%y'); market_data
# Out:
#            Date      Open      High       Low     Close
# 0    2022-05-06  34569.10  34797.95  34353.20  34591.20
# 1    2022-05-05  35705.35  35934.85  35133.80  35232.85
# 2    2022-05-04  36266.15  36309.30  35127.85  35264.55
# 3    2022-05-02  35627.60  36235.25  35618.20  36163.75
# 4    2022-04-29  36474.05  36718.80  35978.95  36088.15
# ...         ...       ...       ...       ...       ...
# 3299 2009-01-07   5416.35   5440.55   4954.00   4984.50
# 3300 2009-01-06   5333.50   5448.80   5276.40   5395.30
# 3301 2009-01-05   5273.45   5371.10   5273.45   5359.40
# 3302 2009-01-02   5154.20   5258.65   5103.60   5195.10
# 3303 2009-01-01   5019.20   5135.15   5019.20   5116.50
#
# [3304 rows x 5 columns]

# %%
merged_df = market_data.merge(F, how = 'left', on = ['Date']); merged_df
# Out:
#            Date      Open      High       Low     Close  \
# 0    2022-05-06  34569.10  34797.95  34353.20  34591.20
# 1    2022-05-05  35705.35  35934.85  35133.80  35232.85
# 2    2022-05-04  36266.15  36309.30  35127.85  35264.55
# 3    2022-05-02  35627.60  36235.25  35618.20  36163.75
# 4    2022-04-29  36474.05  36718.80  35978.95  36088.15
# ...         ...       ...       ...       ...       ...
# 3299 2009-01-07   5416.35   5440.55   4954.00   4984.50
# 3300 2009-01-06   5333.50   5448.80   5276.40   5395.30
# 3301 2009-01-05   5273.45   5371.10   5273.45   5359.40
# 3302 2009-01-02   5154.20   5258.65   5103.60   5195.10
# 3303 2009-01-01   5019.20   5135.15   5019.20   5116.50
#
#                                               Headlines  \
# 0     pm modi likely launch 75 digital banks august ...
# 1     asbadesignated bank branches remain open sunda...
# 2     rbi rate hike shocker home car loans get deare...
# 3     kotak mahindra bank backed phoenix arc set acq...
# ...

# %%
merged_df = merged_df.fillna(''); merged_df
# Out:
#            Date      Open      High       Low     Close  \
# 0    2022-05-06  34569.10  34797.95  34353.20  34591.20
# 1    2022-05-05  35705.35  35934.85  35133.80  35232.85
# 2    2022-05-04  36266.15  36309.30  35127.85  35264.55
# 3    2022-05-02  35627.60  36235.25  35618.20  36163.75
# 4    2022-04-29  36474.05  36718.80  35978.95  36088.15
# ...         ...       ...       ...       ...       ...
# 3299 2009-01-07   5416.35   5440.55   4954.00   4984.50
# 3300 2009-01-06   5333.50   5448.80   5276.40   5395.30
# 3301 2009-01-05   5273.45   5371.10   5273.45   5359.40
# 3302 2009-01-02   5154.20   5258.65   5103.60   5195.10
# 3303 2009-01-01   5019.20   5135.15   5019.20   5116.50
#
#                                               Headlines  \
# 0     pm modi likely launch 75 digital banks august ...
# 1     asbadesignated bank branches remain open sunda...
# 2     rbi rate hike shocker home car loans get deare...
# 3     kotak mahindra bank backed phoenix arc set acq...
# ...

# %%
type(merged_df['Sentiment'][1][1])
# Out:
# float

# %%
from google.colab import files

# %%
merged_df.to_csv('eco_tm_Nifty_merged.csv', encoding = 'utf-8-sig')
files.download('eco_tm_Nifty_merged.csv')

# %%
d1=pd.read_csv('/content/Bus_std_Nifty_merged.csv')
d2=pd.read_csv('/content/Bus_tdy_Nifty_merged.csv')
d3=pd.read_csv('/content/Ind_Exp_Nifty_merged.csv')
d4=pd.read_csv('/content/eco_tm_Nifty_merged.csv')

# %%
d1
# Out:
#       Unnamed: 0        Date      Open      High       Low     Close  \
# 0              0  2022-05-06  34569.10  34797.95  34353.20  34591.20
# 1              1  2022-05-05  35705.35  35934.85  35133.80  35232.85
# 2              2  2022-05-04  36266.15  36309.30  35127.85  35264.55
# 3              3  2022-05-02  35627.60  36235.25  35618.20  36163.75
# 4              4  2022-04-29  36474.05  36718.80  35978.95  36088.15
# ...          ...         ...       ...       ...       ...       ...
# 3299        3299  2009-01-07   5416.35   5440.55   4954.00   4984.50
# 3300        3300  2009-01-06   5333.50   5448.80   5276.40   5395.30
# 3301        3301  2009-01-05   5273.45   5371.10   5273.45   5359.40
# 3302        3302  2009-01-02   5154.20   5258.65   5103.60   5195.10
# 3303        3303  2009-01-01   5019.20   5135.15   5019.20   5116.50
#
#                                               Headlines  \
# 0                                                   NaN
# ...

# %%
d1=d1.drop(d1.columns[0],axis=1)
d2=d2.drop(d2.columns[0],axis=1)
d3=d3.drop(d3.columns[0],axis=1)
d4=d4.drop(d4.columns[0],axis=1)

# %%
S1=d1['Sentiment']
S2=d2['Sentiment']
S3=d3['Sentiment']
S4=d4['Sentiment']

# %%
for  j in range(len(S1)):
  if S1.isna()[j]==False:
    s=S1[j].replace('[','').replace(',','').replace(']','').split()
    for i in range(len(s)):
      s[i]=float(s[i])
    S1[j]=s

for  j in range(len(S2)):
  if S2.isna()[j]==False:
    s=S2[j].replace('[','').replace(',','').replace(']','').split()
    for i in range(len(s)):
      s[i]=float(s[i])
    S2[j]=s

for  j in range(len(S3)):
  if S3.isna()[j]==False:
    s=S3[j].replace('[','').replace(',','').replace(']','').split()
    for i in range(len(s)):
      s[i]=float(s[i])
    S3[j]=s

for  j in range(len(S4)):
  if S4.isna()[j]==False:
    s=S4[j].replace('[','').replace(',','').replace(']','').split()
    for i in range(len(s)):
      s[i]=float(s[i])
    S4[j]=s
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
for j in range(len(S1)):
  if S1.isna()[j]==False:
    s=np.array(S1[j])
    S1[j]=s

for j in range(len(S2)):
  if S2.isna()[j]==False:
    s=np.array(S2[j])
    S2[j]=s

for j in range(len(S3)):
  if S3.isna()[j]==False:
    s=np.array(S3[j])
    S3[j]=s

for j in range(len(S4)):
  if S4.isna()[j]==False:
    s=np.array(S4[j])
    S4[j]=s
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
for j in range(len(S1)):
  if S1.isna()[j]==True:
    S1[j]=np.NaN

for j in range(len(S2)):
  if S2.isna()[j]==True:
    S2[j]=np.NaN

for j in range(len(S3)):
  if S3.isna()[j]==True:
    S3[j]=np.NaN

for j in range(len(S4)):
  if S4.isna()[j]==True:
    S4[j]=np.NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df=S1[0:7]
df=[np.mean(df) if i is np.NaN else i for i in df]
S1[0:7]=df
df=S2[0:7]
df=[np.mean(df) if i is np.NaN else i for i in df]
S2[0:7]=df
df=S3[0:7]
df=[np.mean(df) if i is np.NaN else i for i in df]
S3[0:7]=df
df=S4[0:7]
df=[np.mean(df) if i is np.NaN else i for i in df]
S4[0:7]=df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
for i in range(7,len(S1)):
  if S1.isna()[i]==True:
    S1[i]=np.mean(S1[i-7:i-1])

for i in range(7,len(S2)):
  if S2.isna()[i]==True:
    S2[i]=np.mean(S2[i-7:i-1])

for i in range(7,len(S3)):
  if S3.isna()[i]==True:
    S3[i]=np.mean(S3[i-7:i-1])

for i in range(7,len(S4)):
  if S4.isna()[i]==True:
    S4[i]=np.mean(S4[i-7:i-1])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
zipped=list(zip(S1,S2,S3,S4))
SD=pd.DataFrame(zipped, columns=['Bus_std','Bus_tdy','Ind_exp','eco_tm'])
SD
# Out:
#                                                 Bus_std  \
# 0     [0.82151292, 0.012641424891943332, 0.165845670...
# 1            [0.99989796, 3.2633983e-07, 0.00010168001]
# 2     [0.82151292, 0.012641424891943332, 0.165845670...
# 3     [0.82151292, 0.012641424891943332, 0.165845670...
# 4                  [0.46467537, 0.03789292, 0.49743178]
# ...                                                 ...
# 3299  [0.2666819026776898, 0.3156434601392169, 0.417...
# 3300  [0.2666819026776898, 0.3156434601392169, 0.417...
# 3301  [0.2666819026776898, 0.3156434601392169, 0.417...
# 3302  [0.2666819026776898, 0.3156434601392169, 0.417...
# 3303  [0.2666819026776898, 0.3156434601392169, 0.417...
#
#                                                 Bus_tdy  \
# 0                   [0.69246536, 0.2830311, 0.02450352]
# 1            [0.99995565, 4.0085877e-05, 4.3093996e-06]
# 2                    [0.4945004, 0.5048732, 0.00062641]
# 3            [0.00030031957, 0.99968433, 1.5417747e-05]
# ...

# %%
market_data
# Out:
#            Date      Open      High       Low     Close
# 0    2022-05-06  34569.10  34797.95  34353.20  34591.20
# 1    2022-05-05  35705.35  35934.85  35133.80  35232.85
# 2    2022-05-04  36266.15  36309.30  35127.85  35264.55
# 3    2022-05-02  35627.60  36235.25  35618.20  36163.75
# 4    2022-04-29  36474.05  36718.80  35978.95  36088.15
# ...         ...       ...       ...       ...       ...
# 3299 2009-01-07   5416.35   5440.55   4954.00   4984.50
# 3300 2009-01-06   5333.50   5448.80   5276.40   5395.30
# 3301 2009-01-05   5273.45   5371.10   5273.45   5359.40
# 3302 2009-01-02   5154.20   5258.65   5103.60   5195.10
# 3303 2009-01-01   5019.20   5135.15   5019.20   5116.50
#
# [3304 rows x 5 columns]

# %%
SM=[]
for i in range(len(SD)):
  SM.append(np.mean(SD.iloc[i]))

# %%
market_data['mean_sentment']=SM

# %%
market_data
# Out:
#            Date      Open      High       Low     Close  \
# 0    2022-05-06  34569.10  34797.95  34353.20  34591.20
# 1    2022-05-05  35705.35  35934.85  35133.80  35232.85
# 2    2022-05-04  36266.15  36309.30  35127.85  35264.55
# 3    2022-05-02  35627.60  36235.25  35618.20  36163.75
# 4    2022-04-29  36474.05  36718.80  35978.95  36088.15
# ...         ...       ...       ...       ...       ...
# 3299 2009-01-07   5416.35   5440.55   4954.00   4984.50
# 3300 2009-01-06   5333.50   5448.80   5276.40   5395.30
# 3301 2009-01-05   5273.45   5371.10   5273.45   5359.40
# 3302 2009-01-02   5154.20   5258.65   5103.60   5195.10
# 3303 2009-01-01   5019.20   5135.15   5019.20   5116.50
#
#                                           mean_sentment
# 0     [0.8337576449999999, 0.07719208835347165, 0.08...
# 1     [0.779157295, 0.220632142139165, 0.0002105616799]
# 2     [0.780333985, 0.13505055994597165, 0.084615475...
# 3     [0.6601732523925, 0.25689701222097167, 0.08292...
# ...

# %%
market_data.to_csv('/content/mean_sentiment.csv')
