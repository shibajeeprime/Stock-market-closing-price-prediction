# %%
import time
import pandas as pd
import numpy as np

from selenium import webdriver
from selenium.webdriver.common.keys import Keys


browser = webdriver.Chrome('/home/sysadm/Downloads/chromedriver_linux64/chromedriver')
browser.get("https://www.businesstoday.in/industry/banks")
time.sleep(1)

elem = browser.find_element_by_tag_name("body")

t = 0
while(t<60):
    try:
        loadmorebutton = browser.find_element_by_id("load_more")
        time.sleep(1)
        loadmorebutton.click()
        time.sleep(1)
        t+=1
    except Exception as e:
        print(e, 'E')
        print(type(loadmorebutton))
        print(t)
        if t >= 48:
            break
        else:
            continue
# Out:
# /home/sysadm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   if __name__ == '__main__':
# /home/sysadm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   del sys.path[0]
# /home/sysadm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="load_more"]"}
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# #0 0x5609d447eee3 <unknown>
# #1 0x5609d3f4c608 <unknown>
# #2 0x5609d3f82aa1 <unknown>
# #3 0x5609d3f82c61 <unknown>
# #4 0x5609d3fb5714 <unknown>
# #5 0x5609d3fa029d <unknown>
# #6 0x5609d3fb33bc <unknown>
# #7 0x5609d3fa0163 <unknown>
# ...

# %%
browser.execute_cdp_cmd('Emulation.setScriptExecutionDisabled', {'value': True})
post_elems = browser.find_elements_by_class_name("widget-listing")

headline = []
for post in post_elems:
    head = post.find_elements_by_tag_name("h2")
    for h in head:
        headline.append(h.text)
timeline = []
for i in range(0, 21):
    times = post_elems[i].find_elements_by_tag_name("span")
    for t in times:
        timeline.append(t.text)
for i in range(21, len(post_elems)):
    times = post_elems[i].find_elements_by_tag_name("h5")
    for t in times:
        timeline.append(t.text)


BusinessToday = pd.DataFrame([headline, timeline])
BusinessToday = BusinessToday.T
BusinessToday
# Out:
# /home/sysadm/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#
# /home/sysadm/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py:359: UserWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   warnings.warn("find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead")
#                                                      0             1
# 0         Indian Bank unveils digital broking solution  May 07, 2022
# 1    RBI imposes fine on KKR India Financial Servic...  May 06, 2022
# 2    Easing fit and proper norms could push IDBI Ba...  May 06, 2022
# 3    Federal Bank net profit rises 13% to Rs 541 cr...  May 06, 2022
# 4    Central Bank of India to close 13% of its bran...  May 05, 2022
# ...

# %%
BusinessToday.to_csv('/home/sysadm/Documents/BusinessToday.csv', header = False)

# %%
for i in range(21,400):
    head = post_elems[i].find_elements_by_tag_name('p')
    for h in head:
        print(h.text)

# %%
post_elems[i].text
# Out:
# 'HDFC Bank announces highest dividend in over a decade; check details'
